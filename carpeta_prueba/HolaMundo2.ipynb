# %% [markdown]
# <a href="https://colab.research.google.com/github/a01752336-oss/Repositorio-de-prueba/blob/main/carpeta_prueba/HolaMundo2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # Numpy = Libreria operaciones logicas matematicas dentro del codigo
import pandas as pd

# %% [markdown]
# "Este es un cambio desde mi computadora"
